# %% [markdown]
# # Session - 5 Regression Algorithms part 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1.
# Create a Python script that generates two arrays: one representing the number of hours you spend on Instagram each day for a week, and the other representing your daily phone battery percentage at the end of the day. Plot these as a scatter plot using matplotlib.

# %%
instagram_hours = np.array([1.5, 3.0, 4.5, 2.0, 5.0, 1.0, 3.5])
battery_percentage = np.array([80, 65, 40, 75, 30, 85, 55])

# %%
plt.scatter(instagram_hours, battery_percentage)
plt.show()

# %% [markdown]
# # Task 2.
# Using scikit-learn's LinearRegression, fit a simple linear regression model to predict daily battery percentage based on Instagram usage hours from your generated data. Print the model's slope (coefficient) and intercept.

# %%
from sklearn.linear_model import LinearRegression

# %%
X = instagram_hours.reshape(-1, 1)
y = battery_percentage

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-13.61979167])

# %%
model.intercept_
# Out:
# np.float64(101.31510416666669)

# %% [markdown]
# # Task 3.
# Plot the regression line on top of your scatter plot to visualize the relationship between Instagram hours and battery percentage using matplotlib.<br><br><em><strong>Hint:</strong> Use model.predict() to get the predicted values for your x-axis data and plot them as a line.</em>

# %%
predictions = model.predict(X)
predictions
# Out:
# array([80.88541667, 60.45572917, 40.02604167, 74.07552083, 33.21614583,
#        87.6953125 , 53.64583333])

# %%
plt.scatter(instagram_hours, battery_percentage)
plt.plot(instagram_hours, predictions, color='red')
plt.show()

# %% [markdown]
# # Task 4.
# Calculate the mean squared error (MSE) between your actual battery percentages and the predicted values from your regression model using sklearn.metrics.mean_squared_error. Print the MSE value and explain in one line what a lower MSE indicates.

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(battery_percentage, predictions)
mse
# Out:
# 5.96168154761905
